# %% [markdown]
# # Lesson 3 Assignment
# ## Python Library Management System
#
# Each numbered section is placed in a separate cell to keep the notebook organized.

# %% [markdown]
# ### GitHub Repository Link
#
# https://github.com/mashiurfindu23/AI-assignments

# %% [markdown]
# ### Import Required Libraries

# %%
import pickle
import sqlite3
import requests

# %% [markdown]
# ### 1. Data Types and Variables

# %%
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %% [markdown]
# ### 2. Lists

# %%
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# Add two more books to the list
books.append("Machine Learning with Python")
books.insert(1, "Python for Beginners")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python']

# %% [markdown]
# ### 3. Loops and `range()`

# %%
print("Available books:")

for index in range(len(books)):
    print(index + 1, books[index])
# Out:
# Available books:
# 1 Python Basics
# 2 Python for Beginners
# 3 Advanced Python
# 4 Data Science with Python
# 5 Machine Learning with Python

# %% [markdown]
# ### 4. User Input

# %%
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Artificial Intelligence']

# %% [markdown]
# ### 5. Functions and Conditional Statements

# %%
def check_availability(book_name):
    if book_name in books:
        return True
    else:
        return False

print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %% [markdown]
# ### 6. File Input and Output

# %%
def save_books_to_file(filename):
    with open(filename, 'w', encoding='utf-8') as file:
        for book in books:
            file.write(f"{book}\n")

def read_books_from_file(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        return [line.strip() for line in file]

save_books_to_file("books.txt")
print("Books read from file:", read_books_from_file("books.txt"))
# Out:
# Books read from file: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Artificial Intelligence']

# %% [markdown]
# ### 7. Pickle Serialization

# %%
def save_books_pickle(filename):
    with open(filename, 'wb') as file:
        pickle.dump(books, file)

def load_books_pickle(filename):
    with open(filename, 'rb') as file:
        return pickle.load(file)

save_books_pickle("books.pkl")
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Artificial Intelligence']

# %% [markdown]
# ### 8. SQLite Database Interaction

# %%
def create_books_table():
    with sqlite3.connect('library.db') as conn:
        cursor = conn.cursor()
        cursor.execute('''CREATE TABLE IF NOT EXISTS books
                          (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')

def add_book_to_db(title, quantity):
    with sqlite3.connect('library.db') as conn:
        cursor = conn.cursor()
        cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)",
                       (title, quantity))

create_books_table()
add_book_to_db("Python for Beginners", 10)
print("Book added to the SQLite database successfully.")
# Out:
# Book added to the SQLite database successfully.

# %% [markdown]
# ### 9. Web API Interaction (GitHub API)

# %%
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}

    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        return [repo['name'] for repo in data['items'][:5]]
    except requests.RequestException as error:
        return [f"Unable to retrieve repositories: {error}"]

print("Top 5 Python repositories on GitHub:", get_python_repos())
print("Library Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'project-based-learning']
# Library Management System operations completed.
